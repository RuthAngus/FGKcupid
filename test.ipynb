# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import george
from george.kernels import ExpSquaredKernel
import pandas as pd

# %% [markdown]
# Load the data

# %%
data = pd.read_csv("metcalfe.txt", delim_whitespace=True)
data
# Out:
#         kid,     R,  rerr,    M,  merr,  age,  aerr,      z,   zerr,     y,  \
# 0    3427720  1.125  0.014  1.13   0.04  2.23   0.17  0.0168  0.0016  0.248
# 1    6116048  1.219  0.009  1.01   0.03  6.23   0.37  0.0118  0.0011  0.255
# 2    6603624  1.181  0.015  1.09   0.03  8.11   0.46  0.0309  0.0029  0.250
# 3    6933899  1.599  0.018  1.14   0.03  6.87   0.34  0.0203  0.0022  0.257
# 4    7871531  0.874  0.008  0.84   0.02  9.15   0.47  0.0125  0.0014  0.263
# 5    8006161  0.947  0.007  1.04   0.02  5.04   0.17  0.0427  0.0052  0.259
# 6    8394589  1.116  0.019  0.94   0.04  2.92   0.18  0.0082  0.0005  0.308
# 7    8694723  1.436  0.024  0.96   0.03  4.90   0.54  0.0058  0.0006  0.298
# 8    8760414  1.010  0.004  0.78   0.01  3.69   0.74  0.0032  0.0003  0.238
# 9    9098294  1.154  0.009  1.00   0.03  7.28   0.51  0.0143  0.0018  0.252
# 10   9139151  1.146  0.011  1.14   0.03  1.71   0.19  0.0224  0.0014  0.289
# ...
